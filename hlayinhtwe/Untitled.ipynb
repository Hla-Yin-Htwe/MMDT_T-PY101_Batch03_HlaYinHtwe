# %%
import sys
print(sys.executable)
# Out:
# /opt/homebrew/Cellar/jupyterlab/4.5.0_1/libexec/bin/python

# %%
import sys
# !{sys.executable} -m pip install numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 3.2 MB/s  0:00:01 eta 0:00:01
# ...
