# %% [markdown]
# <a href="https://colab.research.google.com/github/myothida/PythonProgramming/blob/main/Ex1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# This section introduces the Python Programming uisng Colab. Follow the instructions and complete the exercises.

# %% [markdown]
# # Ex 1 : Check Version

# %% [markdown]
# Using the below cell, Import the required library and check the version of the python in your environment.

# %%
import sys
sys.version
# Out:
# '3.14.0 (main, Oct  7 2025, 09:34:52) [Clang 17.0.0 (clang-1700.0.13.3)]'

# %% [markdown]
# # Ex2 : Convert Currency.

# %% [markdown]
# Write a program that asks the user for the amount in usd and converts it to British pounds. The exchange rate is from usd to BP is given as 0.82

# %%
usd_amount = input ("Enter the amount in USD: ")
bp_amount = int(usd_amount) *0.82
print("{} usd is equivalent to {} british pound".format(usd_amount, bp_amount))
# Out:
# Enter the amount in USD:  1500
# 1500 usd is equivalent to 1230.0 british pound

# %% [markdown]
# # Ex 3: Temperature Converter

# %% [markdown]
# Write a program that convert temperature in Feranhite to celsius.

# %%
#°C = 5/9(°F - 32)
temp_F=input("Enter Feranhite")
temp_C=5/9 * int(temp_F )-32
print(temp_C)
print("{} feranhite is equal to {} celsius" .format(temp_F, temp_C))
# Out:
# Enter Feranhite 90
# 18.0
# 90 feranhite is equal to 18.0 celsius

# %% [markdown]
# # Ex 4: Daily Maths

# %% [markdown]
# You are working in a retail shop. Write a program that computes the total cost for a customer that bought 3 differnt types of fruits : apple, orange, mango. Ask the user to enter the quantity and price for each type.

# %%
apple=int(input("Enter the quantity of apple"))
p1=input ("Enter price for apple")

orange=int(input("Enter the quantity of orange"))
p2=int(input ("Enter price for orange"))

mango=int(input("Enter the quantity of mango"))
p3=(input ("Enter price for mango"))

total=int(apple*p1)+int(orange*p2)+int(mango*p3)
print("The quantity are:" ,total)
# Out:
# Enter the quantity of apple 1
# Enter price for apple 1000
# Enter the quantity of orange 1
# Enter price for orange 1000
# Enter the quantity of mango 1
# Enter price for mango 1000
# The quantity are: 3000

# %% [markdown]
# # Ex 5 : Greeting

# %% [markdown]
# Write a program to greet the customer who provides the user name. Your program should ask the name of the customer and print "Hello + customer name"

# %%
name=input("Enter Your Name")
print("Hello", name)
# Out:
# Enter Your Name Hla Yin Htwe
# Hello Hla Yin Htwe

# %% [markdown]
# # Ex 6: Random Number
# Write a program that generates a random number, x, between 1 and 50, a random number y between 2 and 5, and computes x^y.

# %%
from random import randint
x = randint(1,10)
print('A random number between 1 and 10: ', x)
# Out:
# A random number between 1 and 10:  2

# %%
from random import randint
x=randint(1,50)
y=randint(2,5)
result=x*y
print(x)
print(y)
print("Result", result)
# Out:
# 50
# 5
# Result 250

# %% [markdown]
# # Ex 7: Greet many times.
# Write a program that generates a random number between 1 and 10 and prints your name that many times.

# %%
from random import randint
x=randint(1,10)
name="Hla Yin Htwe"
print(x)
print ("Result:", name * x)
# Out:
# 2
# Result: Hla Yin HtweHla Yin Htwe

# %% [markdown]
# # Ex 8: Computing.
# Write a program that asks the user to enter two numbers, x and y, and computes |x-y|/(x+y).

# %%
x=input("Enter a number")
y=input("Enter a number")
result= int(x)-int(y) / int(x+y)
print("Result:", result)
# Out:
# Enter a number 2
# Enter a number 3
# Result: 1.8695652173913044

# %% [markdown]
# # Ex 9: Computing
#
# Write a program that asks the user for a number of seconds and prints out how many minutes and seconds that is. For instance, 200 seconds is 3 minutes and 20 seconds.

# %%
num=int(input("Enter number in seconds"))
# formula=> 1s= 0.0166667 min
total_min=num /60
min=int(total_min)
sec=int((total_min-min)*60)
print(total_min)
print(min)
print(sec)
print("{} seconds is {} minutes and {} seconds".format(num, min,sec))
# Out:
# Enter number in seconds 500
# 8.333333333333334
# 8
# 20
# 500 seconds is 8 minutes and 20 seconds

# %% [markdown]
# # Ex 10: Using Math Module
#
# Write a program that asks the user for a number and then prints out the sine, cosine, and tangent of that number.

# %%
import math

num = float(input("Enter a number:"))
sine_value = math.sin(num)
print(sine_value)

# %%
import math
num=float(input("Enter an number:"))
sine_value=math.sin(num)
cosine_value=math.cos(num)
tangent_value=math.tan(num)
print(sine_value)
print(cosine_value)
print(tangent_value)
# Out:
# Enter an number: 30
# -0.9880316240928618
# 0.15425144988758405
# -6.4053311966462765
