# %% [markdown]
# <a href="https://colab.research.google.com/github/myothida/PythonProgramming/blob/main/Ex4_Looping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercises are extracted from A_Practical_Introduction_to_Python_Programming_Heinold.pdf

# %% [markdown]
# Ex 1: Write a program that uses a while loop (not a for loop) to read through a string and print
# the characters of the string one-by-one on separate lines.

# %%
text="Hello"
idx=0
while idx < len(text):
    print(text[idx])
    idx +=1
# Out:
# H
# e
# l
# l
# o

# %% [markdown]
# Ex 2: A good program will make sure that the data its users enter is valid. Write a program that
# asks the user for a weight and converts it from kilograms to pounds. Whenever the user
# enters a weight below 0, the program should tell them that their entry is invalid and then ask

# %%
# 1kg=2.20462lb
weight=True
while weight:
    wgt=float(input("Enter your weight in kilograms"))
    if wgt>0:
        lb=2.20462 * wgt
        print("You weight in {} kg is equal to {} pounds".format(wgt, lb))
        weight=False
    else:
        print("The entry is invalid")
# Out:
# Enter your weight in kilograms 35.5
# You weight in 35.5 kg is equal to 78.26401 pounds

# %% [markdown]
# Ex 3: Write a program that allows the user to enter any number of test scores. The user indicates
# they are done by entering in a negative number. Print how many of the scores are A’s (90 or
# above). Also print out the average

# %%
# ask user to enter score 
# if negative stop
# >=90 => A's

counter=0
total=0
a_count
score=float(input("Enter test score (negative number to stop)"))
while score > 0:
    total += score
    counter += 1

    if score >= 90:
        a_count +=1
    score=float(input("Enter test score (negative number to stop)"))

if counter > 0:
    avg=total/ counter
    print("Score of A's: {}".format(a_count))
    print("Score average is: {} ".format(avg))
# Out:
# Enter test score (negative number to stop) 45
# Enter test score (negative number to stop) 67
# Enter test score (negative number to stop) 78
# Enter test score (negative number to stop) 89
# Enter test score (negative number to stop) 90
# Enter test score (negative number to stop) -2
# Score of A's: 2
# Score average is: 73.8

# %% [markdown]
# Ex 4: Write a program that asks the user for a string and a letter. Using a for loop, the
# program should print the index of the first occurrence of that letter and a message if the
# string does not contain the letter.

# %%
text=input("Enter a string")
letter=input("Enter a  letter")
for i,char in enumerate(text):
    if char==letter:
        print("The index of the first occurrence of that letter is", i)
        break

else:
    print("The string does not contain the letter")
# Out:
# Enter a string hello world
# Enter a  letter o
# The index of the first occurrence of that letter is 4

# %% [markdown]
# Ex 5: Write a program in which you have a list that contains seven integers that can be 0 or 1. Find the first zero entry in the list and change it to a 1. If there are no zero entries, print a message saying so.

# %%
numbers = [1, 1, 0, 1, 0, 1, 1]
for i,num in enumerate(numbers):
    if num== 0:
        numbers[i] = 1
        print(f"First zero found at index '{i}' and changed to '1'.")
        print("Updated list that changed to 1:", numbers)
        break
else:
    print("There are no zero entries in the list.")
# Out:
# First zero found at index '2' and changed to '1'.
# Updated list that changed to 1: [1, 1, 1, 1, 0, 1, 1]
